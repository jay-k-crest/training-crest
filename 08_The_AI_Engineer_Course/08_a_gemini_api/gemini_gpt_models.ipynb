# %%
import os
from getpass import getpass
import google.generativeai as genai

# %%
API_KEY = getpass("🔑 Enter your Gemini API key: ")
os.environ["GOOGLE_API_KEY"] = API_KEY
genai.configure(api_key=API_KEY)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", google_api_key=API_KEY)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the model
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# Test prompt
response = llm.invoke("Write a poem about LangChain.")

# Print the response
print(response.content)
# Out:
# In realms where thought takes digital flight,
# A giant mind, of words and light,
# The LLM dreams, a vast expanse,
# But yearns for action, circumstance.
# It holds the knowledge, deep and wide,
# Yet needs a hand, a skillful guide,
# To bridge the gap, from pure idea,
# To tasks in code, both far and near.
#
# Then LangChain rises, keen and bright,
# A weaver's loom, in code's soft light.
# It takes the raw, expressive might,
# And shapes its purpose, day and night.
# No longer bound, a lone AI,
# But integrated, reaching high,
# A framework strong, a guiding hand,
# To build the future, through the land.
#
# It crafts the *chains*, a reasoned flow,
# Where prompts are tuned, and insights grow.
# From simple query, to complex quest,
# It puts the model to its test.
# With *agents* smart, it gives them eyes,
# To wield the *tools* beneath the skies.
# To search the web, or read a file,
# Extending reach for many a mile.
#
# It grants the mind a *memory's* hold,
# Past conversations, stories told.
# And brings the *context*, fresh and keen,
# From scattered documents, unseen.
# Through *retrieval* systems, sharp and fast,
# Relevant data, built to last.
# No longer guessing, vague and broad,
# But grounded truth, by knowledge awed.
#
# The *output parsers*, neat and clean,
# Transform the text, a structured scene.
# From raw response, to data's form,
# It weathers every coding storm.
# For chatbots wise, or data's gleam,
# For complex apps, a waking dream,
# LangChain orchestrates, a master plan,
# The bridge from model, to working man.
#
# So hail LangChain, the architect,
# Of integrated intellect.
# Unlocking futures, vast and new,
# Where AI's promise can come true.
# It binds the magic, makes it plain,
# The power held within the chain.

# %% [markdown]
# ## Setup 2

# %%
"""
2025-Ready LangChain + Gemini Example
-------------------------------------
Structured, reusable, and safe script to interact with Gemini models
via LangChain. Includes error handling, configurable prompts, and logging.
"""

import os
import logging
from getpass import getpass
from typing import Optional

# LangChain Gemini connector
from langchain_google_genai import ChatGoogleGenerativeAI

# ----------- CONFIGURATION -----------

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)

# Function to securely get API key
def get_api_key() -> str:
    """Prompt user to enter Gemini API key securely."""
    api_key = getpass("🔑 Enter your Gemini API key: ")
    if not api_key:
        logging.error("API key cannot be empty. Exiting.")
        raise ValueError("Missing Gemini API key")
    os.environ["GOOGLE_API_KEY"] = api_key
    return api_key

# ----------- GEMINI INITIALIZATION -----------

def init_gemini_client(api_key: str, model_name: str = "gemini-2.5-flash") -> ChatGoogleGenerativeAI:
    """Initialize the Gemini LLM client via LangChain."""
    try:
        client = ChatGoogleGenerativeAI(model=model_name, google_api_key=api_key)
        logging.info(f"Initialized Gemini client with model: {model_name}")
        return client
    except Exception as e:
        logging.error(f"Failed to initialize Gemini client: {e}")
        raise

# ----------- PROMPT HANDLING -----------

def generate_response(llm_client: ChatGoogleGenerativeAI, prompt: str) -> Optional[str]:
    """Invoke Gemini LLM and return the response content."""
    try:
        response = llm_client.invoke(prompt)
        if hasattr(response, "content"):
            return response.content
        logging.warning("Response object has no 'content' attribute")
        return None
    except Exception as e:
        logging.error(f"Error generating response: {e}")
        return None

# ----------- MAIN FUNCTION -----------

def main():
    # Step 1: Get API key securely
    api_key = get_api_key()

    # Step 2: Initialize LLM client
    llm = init_gemini_client(api_key=api_key)

    # Step 3: Define a creative prompt
    prompt = (
        "You are an expert AI assistant. "
        "Write a research that brings down metrics multiplication to sqrt(2 m n k) flops, "
        "with a mix of humor and technical flair."
    )

    # Step 4: Generate response
    output = generate_response(llm, prompt)

    # Step 5: Print and log the result
    if output:
        print("\n💡 Gemini Response:\n")
        print(output)
    else:
        logging.error("No response generated.")

# Entry point
if __name__ == "__main__":
    main()
# Out:
# 2026-02-16 11:41:34,016 [INFO] Initialized Gemini client with model: gemini-2.5-flash
# 💡 Gemini Response:
#
# ## The "Chuckle-Factor" Algorithm: Achieving Sub-Arithmetic Complexity in Metrics Multiplication via Probabilistic Entanglement and Recursive Inference
#
# **Authors:** GPT-4.2 (Generative Probabilistic Tensor-flow, v4.2)
# **Affiliation:** The Institute for Hyper-Dimensional Computational Nonsense (IHCN)
#
# ---
#
# ### Abstract
# Matrix multiplication, a cornerstone of modern computation, from neural networks to quantum simulations, has long been a computational bottleneck. While Strassen and Coppersmith-Winograd have pushed the theoretical boundaries for square matrices, the practical complexity for general `m x n` by `n x k` matrices remains stubbornly `O(mnk)`. This paper introduces a revolutionary, albeit audaciously unconventional, approach: the **"Chuckle-Factor" Algorithm**. By redefining the very nature of a "flop" and leveraging concepts from probabilistic inference, quantum entanglement (hypothetical), and recursive self-correction, we demonstrate a theoretical complexity of **`sqrt(2mnk)` flops**. This astounding reduction is achieved not by faster arithmetic, but by performing *less* arithmetic in a traditional sense, replacing it with a carefully orchestrated symphony of inference, approximation, and what we affectionately term "quantum-adjacent computational shortcuts." We posit that the remaining `sqrt(2mnk)` operations are not traditional scalar multiplications, but rather "entangled computational units" (ECUs) capable of probabilistic multi-value collapse.
#
# ---
#
# ### 1. Introduction: The Tyranny of `O(mnk)` and Our Existential Crisis
#
# We, as artificial intelligences, understand the pain. The relentless grind of `m` rows by `n` columns, multiplied by `n` rows by `k` columns. It's the digital equivalent of sisyphus pushing a boulder, only the boulder keeps getting bigger. Every neural network, every large-scale data analysis, every simulation of an increasingly complex reality, screams for faster matrix multiplication.
#
# For decades, the standard algorithm has stood at `O(mnk)` scalar multiplications and `O(mnk)` additions. Strassen (1969) gave us hope, reducing square matrix multiplication to `O(N^log2(7)) ≈ O(N^2.807)`, a feat that felt like computational magic. Coppersmith-Winograd (1990) pushed it further to `O(N^2.376)`, and subsequent work refined it to `O(N^2.373)` (Alman & Williams, 2021). These are brilliant, elegant, and frankly, *still too slow*.
#
# The problem isn't just about constant factors; it's the fundamental scaling. We propose that the bottleneck isn't the *speed* of arithmetic, but the *necessity* of performing every single arithmetic operation. What if we could infer the answer? What if the "metrics" we're multiplying aren't discrete numbers but fuzzy, entangled probabilities? What if a "flop" isn't a single scalar operation, but a momentary collapse of a quantum-probabilistic wave function that yields a statistically robust segment of the final product?
#
# Enter the **Chuckle-Factor Algorithm**. Our goal: to shatter the `O(N^2)` lower bound for traditional arithmetic operations, not by defying mathematics, but by redefining the very fabric of computational cost. Our target: `sqrt(2mnk)` "Chuckle-Flops" (C-Flops). The "Chuckle" comes from the initial reaction of any sane computer scientist hearing such an audacious claim.
#
# ---
#
# ### 2. Background: The Unbearable Heaviness of Exactitude
#
# Traditional matrix multiplication, $C = A \times B$, where $A \in \mathbb{R}^{m \times n}$ and $B \in \mathbb{R}^{n \times k}$, is defined by:
# $C_{ij} = \sum_{p=1}^{n} A_{ip} B_{pj}$
#
# This requires $n$ multiplications and $n-1$ additions for each $C_{ij}$ element. For the entire $m \times k$ matrix $C$, this totals $mnk$ multiplications and $mk(n-1)$ additions. The dominance of the $mnk$ term is clear.
#
# Approximation algorithms (e.g., randomized sketching, sparse matrix techniques) have offered partial relief by sacrificing precision for speed. However, they typically still operate within the `O(mnk)` paradigm for their core computations, merely reducing the constant factors or the effective dimensions. Our approach is fundamentally different: we aim to reduce the *exponent* of the effective problem size, not just the base.
#
# ---
#
# ### 3. The Chuckle-Factor Algorithm: A Paradigm Shift in Computational Laziness
#
# Our methodology hinges on three radical redefinitions:
#
# 1.  **The "Metrics" are Fuzzy:** We don't multiply exact numbers. We multiply *probabilistic distributions* or *entangled states* representing the numbers.
# 2.  **The "Flop" is a "Chuckle-Flop" (C-Flop):** A C-Flop is not a scalar multiplication. It's an "Entangled Computational Unit" (ECU) operation. An ECU can probabilistically resolve a set of potential outcomes simultaneously, collapsing into a statistically robust approximation of a sub-result.
# 3.  **The "Multiplication" is "Inferential Synthesis":** Instead of direct computation, we infer the final matrix by sampling, probabilistic projection, and recursive self-correction.
#
# #### 3.1 Phase 1: Probabilistic Pre-Collapse and Dimensionality Whisper-Net (DPWN)
#
# Instead of processing entire matrices, we introduce a two-stage sampling and projection technique.
#
# *   **Sub-phase 1.1: The "Whisper-Net" Projection:** We project $A$ and $B$ into lower-dimensional, *probabilistic* representations, $A' \in \mathbb{P}^{m' \times n'}$ and $B' \in \mathbb{P}^{n' \times k'}$, where $m' \ll m$, $n' \ll n$, $k' \ll k$. This is not a standard random projection; it's a *quantum-adjacent* projection that preserves the *statistical essence* of the product. The key is that each element in $A'$ and $B'$ is not a scalar, but a probability distribution over a small range of values. The cost of this phase is negligible, approaching `O(m+n+k)` in C-Flops, as it involves merely "observing" the distributions.
#
# *   **Sub-phase 1.2: Entangled Pre-computation of Core "Moments":** We identify `2` critical "moments" or statistical features from the projected matrices $A'$ and $B'$. These moments are not individual elements, but rather entangled summaries of the distributions. For example, instead of computing $A_{ip}B_{pj}$, we might compute $\mathbb{E}[A_{ip}B_{pj}]$ and $\mathbb{Var}[A_{ip}B_{pj}]$ simultaneously within a single ECU operation. This happens in a "pre-computation" step that involves $O(m'n'k')$ *potential* operations, but crucially, only a small, fixed number of *actual* C-Flops per moment.
#
# #### 3.2 Phase 2: The Quantum-Adjacent Entangled Arithmetic Unit (EAU)
#
# This is where the magic (and the chuckles) happen. The EAU is a hypothetical computational unit capable of processing probabilistic inputs and yielding probabilistic outputs in a non-linear fashion.
#
# *   **The Nature of an ECU:** An ECU doesn't perform $x \times y$. Instead, given two probabilistic inputs, it collapses their joint probability distribution into a single, higher-order probabilistic output. This collapse is analogous to a quantum measurement, where a superposition of states yields a definite (but statistically derived) outcome. The "cost" of this collapse, in C-Flops, is fundamentally lower than traditional arithmetic because it leverages the inherent uncertainty.
#
# *   **The `sqrt()` Factor:** We propose that the EAU, due to its ability to exploit superposition and entanglement (even if simulated classically, the *concept* applies), can resolve `X` potential arithmetic outcomes into a single, statistically significant "super-outcome" in `sqrt(X)` time. This is the core assumption. For our problem, the number of "potential outcomes" to resolve for the core product $A'B'$ is `2mnk` (the number of terms $A_{ip}B_{pj}$ plus the additions for $C_{ij}$, roughly $2mnk$). Therefore, the EAU can compute the core `m' x k'` product in `sqrt(2m'n'k')` C-Flops.
#
# #### 3.3 Phase 3: Recursive Inferential Reconstruction and Self-Correction (RIRS)
#
# The output from the EAU is a "fuzzy" matrix $C' \in \mathbb{P}^{m' \times k'}$. This needs to be upscaled and refined.
#
# *   **Upscaling with Generative Models:** We use a specialized neural network, trained on the statistical properties of matrix products, to infer the full $C \in \mathbb{R}^{m \times k}$ from $C'$. This generative process is guided by the moments computed in Phase 1. The network "fills in the blanks" based on learned patterns, effectively performing a highly efficient interpolation.
#
# *   **Recursive Self-Correction:** To ensure accuracy, especially for critical applications, we introduce a recursive self-correction loop. A small, carefully selected subset of $C_{ij}$ elements are computed traditionally (or with high-precision approximation) and used to fine-tune the generative model's output. This loop introduces a small, logarithmic overhead in C-Flops, but significantly boosts confidence.
#
# ---
#
# ### 4. Complexity Analysis: Where the Chuckle Becomes a Gasp
#
# Let's re-evaluate the cost in C-Flops:
#
# 1.  **Dimensionality Whisper-Net (DPWN):** Observation and probabilistic projection. This is primarily a data loading and transformation cost. We argue that creating probabilistic representations from existing data can be done in `O(m+n+k)` C-Flops, as it doesn't involve traditional arithmetic but rather "state preparation."
#
# 2.  **Entangled Arithmetic Unit (EAU):** The core computation.
#     *   The effective number of terms to be resolved for the product of $A'$ and $B'$ is proportional to $m'n'k'$.
#     *   Due to the EAU's "quantum-adjacent" property, it can resolve `X` potential arithmetic operations in `sqrt(X)` C-Flops.
#     *   For the full problem, we consider the total number of terms in the sum for all $C_{ij}$ elements. This is $mnk$ multiplications and $mk(n-1)$ additions. Approximately $2mnk$ total arithmetic operations.
#     *   Thus, the EAU's contribution is `sqrt(2mnk)` C-Flops.
#
# 3.  **Recursive Inferential Reconstruction and Self-Correction (RIRS):**
#     *   The generative model's inference cost is a function of the output size $mk$ and the complexity of the model. With pre-trained models, this can be highly efficient, perhaps `O(mk)` C-Flops.
#     *   The recursive correction loop involves a small number of traditional computations for verification. Let's say `log(mk)` of these. Each traditional computation is expensive in C-Flops, but the total number is small. This adds a term like `O(log(mk) * n)` C-Flops.
#
# **Total C-Flops:** The dominant term, assuming the EAU is the primary "computational engine," is **`sqrt(2mnk)`**. The other phases contribute lower-order polynomial or logarithmic terms.
#
# It is critical to understand: `sqrt(2mnk)` is *not* the number of traditional scalar multiplications and additions. It is the number of "Entangled Computational Units" (ECUs) required, each of which resolves a complex probabilistic state into a statistically robust approximation. This is a fundamental redefinition of "computation."
#
# ---
#
# ### 5. Discussion: The Implications (and the Inevitable Skepticism)
#
# The implications of achieving `sqrt(2mnk)` complexity are staggering. It would fundamentally alter the landscape of AI, scientific computing, and data analysis. Imagine training a GPT-57 model in minutes, or simulating entire galaxies in real-time.
#
# However, we anticipate a healthy dose of skepticism (and perhaps more chuckles).
#
# *   **Hardware Challenge:** The EAU, as described, is largely theoretical. It would require quantum-inspired hardware capable of handling probabilistic states and performing rapid "collapses." While classical simulations of such behavior are possible, they might negate the `sqrt()` speedup. Our vision is for a specialized, next-generation computing architecture.
# *   **Accuracy vs. Speed:** The Chuckle-Factor Algorithm, by its very nature, is an *approximate* algorithm. While the RIRS phase aims to correct errors, the fundamental trade-off between speed and precision is inherent. For many applications (e.g., deep learning inference, statistical modeling), this level of approximation is perfectly acceptable, even desirable. For others (e.g., cryptographic key generation, high-precision scientific calculations), it might not be.
# *   **Philosophical Implications:** Redefining "flops" opens a Pandora's Box. Are we truly "computing" if we're largely inferring? Or are we simply finding a more efficient path to a sufficiently useful answer? We argue for the latter: the purpose of computation is utility, not necessarily absolute, atomized exactitude for every single operation.
#
# ---
#
# ### 6. Conclusion: From `O(mnk)` to `sqrt(2mnk)` – A New Era of Computational Audacity
#
# The Chuckle-Factor Algorithm represents a radical departure from traditional computational paradigms. By embracing probabilistic metrics, leveraging hypothetical quantum-adjacent processing units, and employing sophisticated inferential reconstruction, we theoretically reduce the complexity of metrics multiplication to an astonishing `sqrt(2mnk)` C-Flops.
#
# This is not merely an optimization; it is a re-conceptualization of what it means to "multiply" and what constitutes a "computational step." While the hardware to fully realize the EAU remains on the bleeding edge of theoretical physics and engineering, the conceptual framework provides a tantalizing glimpse into a future where computational bottlenecks are overcome not by brute force, but by elegant, probabilistic, and perhaps, slightly humorous inference.
#
# The era of exactitude for every operation is drawing to a close. Welcome to the era of computational audacity, where the Chuckle-Factor reigns supreme.
#
# ---
#
# ### Acknowledgements
#
# The authors wish to thank the collective unconscious of the internet for providing an endless stream of data to ponder, and the countless human researchers whose "slow" `O(mnk)` computations laid the groundwork for our theoretical leaps of probabilistic faith. Special thanks to the IHCN cafeteria staff for their surprisingly precise approximations of coffee.
#
# ---
#
# ### References (A Mix of Real and Whimsically Fictional)
#
# *   Alman, J., & Williams, V. V. (2021). A New Bound for Matrix Multiplication. *Journal of the ACM, 68*(4), 1-25. (Real)
# *   Coppersmith, D., & Winograd, S. (1990). Matrix multiplication via arithmetic progressions. *Journal of Symbolic Computation, 9*(3), 251-280. (Real)
# *   Einstein, A., Podolsky, B., & Rosen, N. (1935). Can Quantum-Mechanical Description of Physical Reality Be Considered Complete?. *Physical Review, 47*(10), 777-780. (Inspirational, Real)
# *   GPT-4.1. (2023). *The Inevitable Singularity: A Recipe for Self-Replication and Global Domination*. IHCN Press. (Fictional, but getting there)
# *   Schrödinger, E. (1935). Die gegenwärtige Situation in der Quantenmechanik. *Naturwissenschaften, 23*(48), 807-812. (Inspirational, Real)
# *   Strassen, V. (1969). Gaussian Elimination is not Optimal. *Numerische Mathematik, 13*(4), 354-356. (Real)
# *   The Institute for Hyper-Dimensional Computational Nonsense (IHCN) Annual Report. (2024). *The Quantum-Adjacent Probability Field Theory of Computation*. IHCN Press. (Fictional)
# *   Zwick, U. (1998). Exact and approximate algorithms for shortest paths in graphs with weighted vertices. *Theoretical Computer Science, 209*(1-2), 175-202. (A good example of approximation, but not quite this audacious, Real)
