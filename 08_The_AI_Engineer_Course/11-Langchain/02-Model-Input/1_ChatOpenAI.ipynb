# %%
import google.generativeai as genai
from getpass import getpass

api_key = getpass("🔑 Enter your Gemini API key: ")
genai.configure(api_key=api_key)

# %%
# Initialize the model
model = genai.GenerativeModel('gemini-2.5-flash')

response = model.generate_content("I've recently adopted a dog. Could you suggest some dog names?")

print(response.text)
# Out:
# Congratulations on your new family member! Naming a dog is one of the first fun things you get to do together. To help you out, I've organized some suggestions into categories. Many names are unisex, so feel free to mix and match!
#
# ### Classic & Timeless
#
# *   Max
# *   Bella
# *   Charlie
# *   Lucy
# *   Buddy
# *   Daisy
# *   Cooper
# *   Bailey
# *   Sadie
# *   Rocky
# *   Bear
# *   Maggie
# *   Duke
# *   Lily
#
# ### Cute & Sweet
#
# *   Honey
# *   Cookie
# *   Peanut
# *   Muffin
# *   Pip
# *   Sprinkles
# *   Pudding
# *   Pippin
# *   Gizmo
# *   Sparky
# *   Dixie
# *   Coco
# *   Rosie
#
# ### Strong & Noble
#
# *   Hunter
# *   Duke
# *   King
# *   Caesar
# *   Athena
# *   Freya
# *   Zeus
# *   Thor
# *   Apollo
# *   Maverick
# *   Ranger
# *   Diesel
# *   Axel
# *   Willow
# *   Sterling
#
# ### Food & Drink Inspired
#
# *   Oreo
# *   Mocha
# *   Mochi
# *   Ginger
# *   Biscuit
# *   Waffle
# *   Taco
# *   Muffin
# *   Sugar
# *   Honey
# *   Peaches
# *   Olive
# *   Bean
# *   Sushi
# *   Chai
# *   Winnie (the Pooh, and honey!)
#
# ### Nature & Celestial Inspired
#
# *   River
# *   Willow
# *   Skye
# *   Forrest
# *   Aspen
# *   Clover
# *   Sunny
# *   Luna
# *   Nova
# *   Stone
# *   Blaze
# *   Cedar
# *   Dusty
# *   Hazel
# *   Rain
#
# ### Pop Culture & Literary (Just a few ideas!)
#
# *   **Star Wars:** Chewie, Leia, Yoda, Kylo, Rey, Finn
# *   **Harry Potter:** Dobby, Luna, Sirius, Hagrid, Niffler
# *   **Marvel/DC:** Loki, Thor, Captain, Wanda, Harley, Bruce
# *   **Disney:** Nala, Simba, Stitch, Gus, Remy
# *   **Literary:** Gatsby, Sherlock, Frodo, Arya, Scout
#
# ### Unique & Uncommon
#
# *   Ezra
# *   Milo
# *   Jasper
# *   Finn
# *   Quinn
# *   Piper
# *   Rowan
# *   Leo
# *   Zoe
# *   Asher
# *   Kai
# *   Rune
# *   Zephyr
# *   Ziggy
# *   Bodhi
#
# ### Tips for Choosing the Perfect Name:
#
# 1.  **Say it Out Loud:** Practice calling the name in different tones. Does it feel right? Is it easy to pronounce?
# 2.  **Keep it Short & Sweet:** One or two syllables are often easiest for dogs to learn and for you to call.
# 3.  **Avoid Similar Sounds:** Try not to pick a name that sounds like a common command (e.g., "Kit" sounds like "Sit").
# 4.  **Consider Personality:** Does the name fit your dog's emerging personality? Is he a playful "Ziggy" or a dignified "Duke"?
# 5.  **Look at Appearance:** Does their fur color, markings, or size suggest a name (e.g., "Oreo" for black and white, "Tiny" for a small dog)?
# 6.  **Family Consensus:** Make sure everyone in the household likes the name!
# 7.  **Test It Out:** Try a few names for a day or two and see which one feels most natural.
#
# Good luck and have fun with your new companion!
