# %% [markdown]
# # Solving Ordinary Differential Equations Using NumPy and SciPy
#
# ---
#
# ### Problem Statement
#
# <code>
# Write a NumPy program to create a NumPy array and use SciPy to solve a system of ordinary differential equations (ODEs).
# </code>
#
# ---

# %%
import numpy as np
from scipy.integrate import odeint

def model(y, t):
    dydt = -2 * y
    return dydt

y0 = np.array([1.0])
t = np.linspace(0, 5, 50)

solution = odeint(model, y0, t)

print(solution)
# Out:
# [[1.00000000e+00]
#  [8.15395823e-01]
#  [6.64870339e-01]
#  [5.42132488e-01]
#  [4.42052560e-01]
#  [3.60447814e-01]
#  [2.93907617e-01]
#  [2.39651037e-01]
#  [1.95410448e-01]
#  [1.59336854e-01]
#  [1.29922599e-01]
#  [1.05938339e-01]
#  [8.63816739e-02]
#  [7.04352527e-02]
#  [5.74326067e-02]
#  [4.68303088e-02]
#  [3.81852422e-02]
#  [3.11360865e-02]
#  [2.53882348e-02]
#  [2.07014597e-02]
#  [1.68798839e-02]
#  [1.37637868e-02]
#  [1.12229344e-02]
#  [9.15113387e-03]
#  [7.46179631e-03]
#  [6.08431758e-03]
#  [4.96112714e-03]
#  [4.04528236e-03]
#  [3.29850635e-03]
#  [2.68958845e-03]
#  [2.19307946e-03]
#  [1.78822756e-03]
#  [1.45811248e-03]
#  [1.18893834e-03]
#  [9.69455000e-04]
#  [7.90489299e-04]
#  [6.44561547e-04]
#  [5.25572465e-04]
#  [4.28549342e-04]
#  [3.49437280e-04]
#  [2.84929564e-04]
#  [2.32330217e-04]
#  [1.89441088e-04]
#  [1.54469455e-04]
#  [1.25953686e-04]
#  [1.02702058e-04]
#  [8.37423329e-05]
#  [6.82833669e-05]
#  [5.56786111e-05]
#  [4.54009274e-05]]
