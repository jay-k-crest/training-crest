# %% [markdown]
# ### Multiply a 5x3 matrix by a 3x2 matrix.

# %%
import numpy as np

mat1 = np.random.random((5, 3))
mat2 = np.random.random((3, 2))
result = np.dot(mat1, mat2)
print(result)
# Out:
# [[0.77862321 0.60806819]
#  [0.59754636 0.48574082]
#  [0.14425256 0.2742166 ]
#  [0.25737208 0.58821276]
#  [0.38238391 0.55840214]]
