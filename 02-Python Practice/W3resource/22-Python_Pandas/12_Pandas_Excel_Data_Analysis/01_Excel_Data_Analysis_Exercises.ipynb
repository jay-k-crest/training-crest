# %% [markdown]
# # Display Last Ten Rows of Excel Data
#
# <code>
# Write a Pandas program to import excel data (coalpublic2013.xlsx)
# into a Pandas DataFrame and display the last ten rows.
# </code>

# %%
import pandas as pd

df = pd.read_excel("coalpublic2013.xlsx")

print(df.tail(10))
# Out:
#      Historical Coal Production Data: 2013 Unnamed: 1             Unnamed: 2  \
# 1443                                  2013    3609405                Phoenix
# 1444                                  2013     100515      Mary Lee # 1 Mine
# 1445                                  2013    3609337     Marco Gfcc Project
# 1446                                  2013    1518401                  No. 1
# 1447                                  2013    1519713             # 1 Refuse
# 1448                                  2013    1103254          Fidelity Mine
# 1449                                  2013    1102636                    Wfi
# 1450                                  2013    4407233               Gobco #8
# 1451                                  2013    1518524      Turkey Pen Refuse
# 1452                                  2013    1519685  Fedscreek Refuse Pile
#
#            Unnamed: 3    Unnamed: 4                          Unnamed: 5  \
# ...
