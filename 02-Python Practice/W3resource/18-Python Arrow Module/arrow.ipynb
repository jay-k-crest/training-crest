# %% [markdown]
# Create a new Arrow object, cloned from the current one

# %%
import arrow
a = arrow.utcnow()
print("Current datetime:")
print(a)
cloned = a.clone()
print("\nCloned datetime:")
print(cloned)
# Out:
# Current datetime:
# 2026-01-15T10:45:14.815276+00:00
#
# Cloned datetime:
# 2026-01-15T10:45:14.815276+00:00
