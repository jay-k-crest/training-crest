# %% [markdown]
# ### random

# %% [markdown]
# random element selection

# %%
import random

elements = [1,2,3,4,5,6]
print(random.choice(elements))
print(random.choice(elements))
print(random.choice(elements))
print(random.choice(elements))
# Out:
# 5
# 2
# 1
# 6

# %% [markdown]
# ### decimal module

# %% [markdown]
# Write a Python program to display a given decimal value in scientific notation. Use decimal.Decimal

# %%
from decimal import Decimal


value = Decimal("12345.6789")


scientific = format(value, "E")

print("Scientific notation:", scientific)
# Out:
# Scientific notation: 1.23456789E+4
