# %% [markdown]
# ###  Convert Python Dictionary (Sorted by Key) to JSON Data

# %%
import json

student = {
    "name": "jay",
    "age": 20,
    "marks": 88
}

json_string = json.dumps(student)

print(json_string)
# Out:
# {"name": "jay", "age": 20, "marks": 88}
