# %% [markdown]
# Write a Python program to create a SQLite database connection to a database that resides in the memory.

# %%
import sqlite3


conn = sqlite3.connect(":memory:")
cursor = conn.cursor()


cursor.execute("""
CREATE TABLE users (
    id INTEGER PRIMARY KEY,
    username TEXT,
    age INTEGER
)
""")


cursor.execute("INSERT INTO users (username, age) VALUES (?, ?)", ("jay", 20))
cursor.execute("INSERT INTO users (username, age) VALUES (?, ?)", ("madhav", 70))


cursor.execute("SELECT * FROM users")
users = cursor.fetchall()

print("Users in memory database:")
for user in users:
    print(user)


conn.close()
# Out:
# Users in memory database:
# (1, 'jay', 20)
# (2, 'madhav', 70)
