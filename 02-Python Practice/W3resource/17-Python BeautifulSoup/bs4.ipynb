# %% [markdown]
# bs4

# %%
from bs4 import BeautifulSoup

html = """
<!DOCTYPE html>
<html>
<head>
    <title>BS4 Title Example</title>
</head>
<body>
    <h1>Welcome</h1>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html, 'html.parser')

title = soup.title

# %%
title
# Out:
# <title>BS4 Title Example</title>

# %%
title.text
# Out:
# 'BS4 Title Example'

# %%
title.parent
# Out:
# <head>
# <title>BS4 Title Example</title>
# </head>
