# %%
import ipywidgets as widgets
from IPython.display import display

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.layout.margin = 'auto'
w.layout.height = '300px'

# %%
x = widgets.IntSlider(value=15,description = 'new slider')
display(x)
# Out:
# IntSlider(value=15, description='new slider')

# %%
widgets.Button(
    description='Click me',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check'
)
# Out:
# Button(button_style='success', description='Click me', icon='check', style=ButtonStyle(), tooltip='Click me')

# %%
b1 = widgets.Button(description='Click Me')
b1.style.button_color = 'lightgreen'

def on_button_clicked(b):
    print("Button clicked.")

b1.on_click(on_button_clicked)

display(b1)
# Out:
# Button(description='Click Me', style=ButtonStyle(button_color='lightgreen'))

# %%
b2 = widgets.Button(description='Click Me')
b2.style = b1.style
b2
# Out:
# Button(description='Click Me', style=ButtonStyle(button_color='lightgreen'))
