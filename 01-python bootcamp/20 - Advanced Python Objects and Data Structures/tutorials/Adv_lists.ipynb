# %%
l = [1,2,3]

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.count(10)
# Out:
# 0

# %%
l.count(1)
# Out:
# 1

# %%
x = [1,2,3]
x.append([4,5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
x = [1,2,3]
x.extend([4,5,6])
print(x)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.index(2)
# Out:
# 1

# %%
l.insert(2,3)

# %%
l
# Out:
# [1, 2, 3, 3, 4]

# %%
ele = l.pop()

# %%
ele
# Out:
# 4

# %%
l
# Out:
# [1, 2, 3, 3]

# %%
l.pop(0)
# Out:
# 1

# %%
#remove first ocuurence in list

my_list = [1, 2,2, 3, 4, 5, 6]
print(my_list)
my_list.remove(2)
print(my_list)
# Out:
# [1, 2, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
l.reverse()

# %%
l
# Out:
# [3, 3, 2]

# %%
l.sort()

# %%
l
# Out:
# [2, 3, 3]
