# %%
hex(12)
# Out:
# '0xc'

# %%
hex(512)
# Out:
# '0x200'

# %%
bin(2)
# Out:
# '0b10'

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
pow(2,3,4)
# Out:
# 0

# %%
abs(-2)
# Out:
# 2

# %%
round(2.14)
# Out:
# 2

# %%
round(3.1415,2)
# Out:
# 3.14
