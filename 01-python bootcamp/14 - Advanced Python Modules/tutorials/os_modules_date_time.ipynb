# %% [markdown]
# OS Module and Datetime
#
# The os module allows Python to interact with the operating system (files, folders, paths, environment variables).
# The datetime module works with dates and times, letting you create, format, and manipulate timestamps and calendars.

# %%
pwd
# Out:
# '\\\\wsl.localhost\\Ubuntu\\home\\jay\\crest-training\\01-python bootcamp\\14 - Advanced Python Modules\\tutorials'

# %%
with open('../files/practice.txt', 'w') as f:
    f.write("Hello, this is a test.")

# %%
import os

# %%
os.getcwd()
# Out:
# '\\\\wsl.localhost\\Ubuntu\\home\\jay\\crest-training\\01-python bootcamp\\14 - Advanced Python Modules\\tutorials'

# %%
os.listdir()
# Out:
# ['collection_modules.ipynb', 'os_modules_date_time.ipynb']

# %%
import shutil

# %%
shutil.move('filetomove.txt' , '../files/')
# Out:
# '../files/filetomove.txt'

# %%
#pip install send2trash in terminal

# %%
import send2trash

# %%
shutil.move('../files/filetomove.txt',os.getcwd())
# Out:
# '\\\\wsl.localhost\\Ubuntu\\home\\jay\\crest-training\\01-python bootcamp\\14 - Advanced Python Modules\\tutorials\\filetomove.txt'

# %%
send2trash.send2trash('filetomove.txt')

# %%
os.listdir()
# Out:
# ['collection_modules.ipynb', 'os_modules_date_time.ipynb']

# %%
for folders , sub_folders , files in os.walk('../Example_Top_Level/'):
    print(f"Curently looking at {folders}")
    print('\n')
    print("Sub directoris are : ")
    for sub_folder in sub_folders:
        print(f"Subfolder : {sub_folder}")
    
    print('\n')
    print("The files are : ")
    for f in files:
        print(f"File: {f}")
    print('\n')
# Out:
# Curently looking at ../Example_Top_Level/
#
#
# Sub directoris are :
# Subfolder : Mid-Example-One
#
#
# The files are :
# File: Mid-Example.txt
#
#
# Curently looking at ../Example_Top_Level/Mid-Example-One
#
#
# Sub directoris are :
# Subfolder : Bottom-Level-Two
# Subfolder : Bottom-Level-One
#
#
# The files are :
# File: Mid-Level-Doc.txt
#
#
# Curently looking at ../Example_Top_Level/Mid-Example-One\Bottom-Level-Two
#
#
# Sub directoris are :
#
#
# The files are :
# File: Bottom-Text-Two.txt
#
#
# Curently looking at ../Example_Top_Level/Mid-Example-One\Bottom-Level-One
#
#
# Sub directoris are :
#
#
# The files are :
# File: One_Text.txt

# %% [markdown]
# ### date and time module

# %%
import datetime

# %%
mytime = datetime.time(2,20)

# %%
mytime
# Out:
# datetime.time(2, 20)

# %%
print(mytime)
# Out:
# 02:20:00

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2026-01-09

# %%
today.year
# Out:
# 2026

# %%
today.month
# Out:
# 1

# %%
today.day
# Out:
# 9

# %%
today.ctime()
# Out:
# 'Fri Jan  9 00:00:00 2026'

# %%
from datetime import datetime

# %%
mydate = datetime(2026,1,9,12,1,20)

# %%
print(mydate)
# Out:
# 2026-01-09 12:01:20

# %%
from datetime import date

# %%
date1 = date(2025,12,22)
date2 = date(2026,1,9)

# %%
result  = date2-date1

# %%
result.days
# Out:
# 18

# %%
datetime1 = datetime(2025,12,22,13,33,3)
datetime2 = datetime(2026,1,9,12,10,36)

# %%
mydiff =datetime2-datetime1

# %%
mydiff.resolution
# Out:
# datetime.timedelta(microseconds=1)
