# %% [markdown]
# Python Debugger (pdb)
#
# Python’s debugger (pdb) helps inspect code while it runs. It allows you to pause execution, check variable values, step through lines, and find where bugs occur.

# %%
x= [1,2,3]
y=2
z=3

result = y+z
print(result)
result2 = x+ y
#manually debuggig with print
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 result = y+z
#       6 print(result)
# ----> 7 result2 = x+ y
#       8 #manually debuggig with print
#
# TypeError: can only concatenate list (not "int") to list

# %%
import pdb

# %%
x= [1,2,3]
y=2
z=3

r1 = y+z
pdb.set_trace()
r2 = y+x
# Out:
#     [... skipping 21 hidden frame(s)]
# > c:\users\jaykalsariya\appdata\local\temp\ipykernel_13996\3020498847.py(6)<module>()
# [1, 2, 3]
# 5
# 2
# 2
# 2
# 2
# 2
# 2
