# %%
import shutil

# %%
shutil.unpack_archive('unzip_me_for_instructions.zip','extracted_content','zip')

# %%
import os
import re

# %%
import os


phone_pattern = re.compile(r'\d{3}-\d{3}-\d{4}')

for folder, sub_folders, files in os.walk('./extracted_content/'):
    
    for file in files:
        # Only check text files
        if file.endswith('.txt'):
            full_path = os.path.join(folder, file)

            with open(full_path, 'r', encoding='utf-8', errors='ignore') as f:
                content = f.read()

                match = phone_pattern.search(content)

                if match:
                    print("FOUND PHONE NUMBER!")
                    print("Location:", full_path)
                    print("Phone:", match.group())
                    break
# Out:
# FOUND PHONE NUMBER!
# Location: ./extracted_content/Four\EMTGPSXQEJX.txt
# Phone: 719-266-2837
