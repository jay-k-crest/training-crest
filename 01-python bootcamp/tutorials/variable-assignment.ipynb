# %% [markdown]
# variable assignment

# %%
a=5

# %%
a
# Out:
# 5

# %%
a=10

# %%
a
# Out:
# 10

# %%
a+a
# Out:
# 20

# %%
a=a*a

# %%
a
# Out:
# 100

# %%
type(a)
# Out:
# int

# %%
a=30.1

# %%
type(a)
# Out:
# float

# %%
my_income = 15000
tax_rate = 0.1
total_tax = my_income*tax_rate

# %%
total_tax
# Out:
# 1500.0
