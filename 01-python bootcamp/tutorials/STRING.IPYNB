# %% [markdown]
# strings

# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
print("hello")
# Out:
# hello

# %%
a = "hello world"
print(a)
# Out:
# hello world

# %%
print("print \n world")
# Out:
# print
#  world

# %%
print("print \t world")
# Out:
# print 	 world

# %%
len(a)
# Out:
# 11

# %% [markdown]
# indexing and slicing

# %%
mystr = "hello world"
print(mystr)
# Out:
# hello world

# %%
mystr[0]
# Out:
# 'h'

# %%
mystr[8]
# Out:
# 'r'

# %%
mystr[-2]
# Out:
# 'l'

# %%
mystr = "abcdefghijk"
print(mystr)
# Out:
# abcdefghijk

# %%
mystr[2:]
# Out:
# 'cdefghijk'

# %%
mystr[:3]
# the index does not count
# Out:
# 'abc'

# %%
mystr[3:6]
# Out:
# 'def'

# %%
mystr[3:9]
# Out:
# 'defghi'

# %% [markdown]
# stepsize

# %%
mystr[::2]
# Out:
# 'acegik'

# %%
mystr[::3]
# Out:
# 'adgj'

# %%
mystr[1:6:2]
# Out:
# 'bdf'

# %%
mystr[::-1]
#reverse string
# Out:
# 'kjihgfedcba'

# %% [markdown]
# string properties & methods

# %%
name = "Jay"

# %%
name[0] = 'j'
#immuatable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 name[0] = 'j'
#
# TypeError: 'str' object does not support item assignment

# %%
last = name[1:]
new = 'j'+last
print(new)
# Out:
# jay

# %%
letter = 'z'

# %%
letter*10
# Out:
# 'zzzzzzzzzz'

# %%
x = 'hello world!'

# %%
x.upper()
# Out:
# 'HELLO WORLD!'

# %% [markdown]
# print formatting

# %%
print('this is a string {}'.format('inserted'))
# Out:
# this is a string inserted

# %%
print('the {} {} {}'.format('fox' , 'brown' , 'quick') )
# Out:
# the fox brown quick

# %%
print('the {2} {1} {0}'.format('fox' , 'brown' , 'quick') )
# Out:
# the quick brown fox

# %%
print('the {a} {b} {c}'.format(a='fox' ,c= 'brown' ,b= 'quick') )
# Out:
# the fox quick brown
