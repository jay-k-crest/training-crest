# %% [markdown]
# chaining operators

# %%
1<2<3
# Out:
# True

# %%
1<2>3
# Out:
# False

# %%
1<2 and 2<3
# Out:
# True

# %%
('h' == 'h') and (2 == 2)
# both conditions have to be true
# Out:
# True

# %%
1 == 1 or 2 == 3 
# either or both conditions can be true
# Out:
# True

# %%
not (True)
# Out:
# False

# %%
not(1 == 2)
# Out:
# True
