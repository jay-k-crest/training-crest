# %% [markdown]
# LISTS

# %%
my_list = [1,2,3]

# %%
my_list = ['string' , 100 , 23.2]

# %%
len(my_list)
# Out:
# 3

# %%
my_list = ['one' , 'two' ,'three']

# %%
my_list[0]
# Out:
# 'one'

# %%
my_list[0:]
# Out:
# ['one', 'two', 'three']

# %%
new_list = ['four' , 'five']

# %%
f = my_list+new_list
f
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list [0] = 'ONE ALL CAPS'

new_list
# Out:
# ['ONE ALL CAPS', 'five']

# %%
new_list.append('six')
new_list
# Out:
# ['ONE ALL CAPS', 'five', 'six', 'six']

# %%
my_list =['one' , 'two' , 'three']
my_list
# Out:
# ['one', 'two', 'three']

# %%
my_list.pop()
my_list
#indexing also works starts from 0 and upto n
# Out:
# ['one', 'two']

# %%
new_list = ['q','z','p','r','g']
num_list = [2,3,1,4,8]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['g', 'p', 'q', 'r', 'z']

# %%
num_list.reverse()
num_list
# Out:
# [8, 4, 1, 3, 2]

# %% [markdown]
# dictionaries
# {key:value} retrive by key
# list when want to access by location

# %%
my_dict = {'key1':'value1' , 'key2':'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices = {'apple': 2.99 , 'oranges':1.99 , 'milk':5.80}
prices['apple']
# Out:
# 2.99

# %%
d= {'k1':123 , 'k2':[0,1,2] , 'k3':{'insideKey':100}}

# %%
d['k2']
# Out:
# [0, 1, 2]

# %%
d['k3']['insideKey']
# Out:
# 100

# %%
d = {'key1':['a','b','c']}

# %%
d['key1'][2].upper() #onliner
# Out:
# 'C'

# %%
d = {'k1':100 , 'k2':200 }

# %%
d['k3'] = 300

# %%
d['k1']="new value"

# %%
d
# Out:
# {'k1': 'new value', 'k2': 200, 'k3': 300}

# %%
d = {'k1':100 , 'k2':200 , 'k3':300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items()
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 300)])

# %% [markdown]
# tuples are immutable and use parenthesis : (1,2,3)

# %%
tuple1 = (1,2,3)

# %%
my_list = [1,2,3]

# %%
type
# Out:
# type

# %%
type(my_list)
# Out:
# list

# %%
t = ('one' , 2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t = ('a','a','b')

# %%
t.count('a')
# Out:
# 2

# %%
t.index('a')
# Out:
# 0

# %%
t.index('b')
# Out:
# 2

# %%
t
# Out:
# ('a', 'a', 'b')

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0] = 'NEW'
my_list
# Out:
# ['NEW', 2, 3]

# %%
t[0] = 'new'
#tupes are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 t[0] = 'new'
#       2 #tupes are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# SETS ARE UNIQUE ELEMENT WITH UNORDERED COLLECTION OF ELEMENTS

# %%
my_set = set()

# %%
my_set
# Out:
# set()

# %%
my_set.add(1)
my_set
# Out:
# {1}

# %%
my_set.add(2)
my_set
# Out:
# {1, 2}

# %%
my_set.add(2)
my_set
# Out:
# {1, 2}

# %%
my_list = [1,1,1,1,1,2,2,2,3,4,5,5,5]

# %%
set(my_list)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# BOOLENAS  true or flase 2 values

# %%
True
# Out:
# True

# %%
type(False)
# Out:
# bool

# %%
1>2
# Out:
# False

# %%
1==1
# Out:
# True
