# %%
my_file = open("../resources/test.txt")

# %%
pwd
# Out:
# '\\\\wsl.localhost\\Ubuntu\\home\\jay\\crest-training\\01-python bootcamp\\tutorials'

# %%
my_file.read()
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line '

# %%
my_file.read()
#CURSOR at end thats why no output
# Out:
# ''

# %%
my_file.seek(0)
#set cursor to beginning
contents = my_file.read()

# %%
contents
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line '

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line ']

# %%
with open("../resources/test.txt") as my_file:
    contents = my_file.read()

# %%
contents
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line '

# %%
with open("../resources/test.txt",mode='r') as my_file:
    contents = my_file.read()

# %%
 contents
# Out:
# 'hello this is a text file\nthis is the second line\nthis is the third line '

# %%
with open("../resources/test.txt", "w") as my_file:
    my_file.read()
    # This will cause an error because the file is opened in write mode
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[16], line 2
#       1 with open("../resources/test.txt", "w") as my_file:
# ----> 2     my_file.read()
#       3     # This will cause an error because the file is opened in write mode
#
# UnsupportedOperation: not readable

# %% [markdown]
# | Character | Meaning                                                         |
# | --------- | --------------------------------------------------------------- |
# | `r`       | Open for reading (default)                                      |
# | `w`       | Open for writing, truncating the file first                     |
# | `x`       | Create a new file and open it for writing                       |
# | `a`       | Open for writing, appending to the end of the file if it exists |
# | `b`       | Binary mode                                                     |
# | `t`       | Text mode (default)                                             |
# | `+`       | Open a disk file for updating (reading and writing)             |

# %%
with open("../resources/test.txt") as my_file:
    contents = my_file.read()

# %%
contents
# Out:
# 'one on first \ntwo on second\nthree on third'

# %%
with open("../resources/test.txt" , mode='a') as my_file:
    my_file.write("\nThis is a new line added to the file.")
    #cursor is at the end of the file in append mode

# %%
with open("../resources/123.txt",mode='w') as my_file:
    my_file.write("Hello World")

# %%
with open("../resources/123.txt") as my_file:
    print(my_file.read())
# Out:
# Hello World
