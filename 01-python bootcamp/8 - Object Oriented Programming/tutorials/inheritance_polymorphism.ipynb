# %%
class Animal():
    def __init__(self):
        print("Animal Created")
    def who_am_i(self):
        print("I am an animal")
    def eat(self):
        print("I am eating")

# %%
myanimal = Animal()
# Out:
# Animal Created

# %%
myanimal.who_am_i()
# Out:
# I am an animal

# %%
class Dog(Animal):
    def __init__(self):
        super().__init__()
        print("Dog Created")
    def who_am_i(self):
        print("I am a dog")

# %%
dog = Dog()
# Out:
# Animal Created
# Dog Created

# %%
dog.who_am_i()
# Out:
# I am a dog

# %% [markdown]
# Polymorphisam
#
# Same name different params

# %%
class dog():
    def __init__(self,name):
        self.name = name
    def speak(self):
        return self.name + " says Woof!"

# %%
class cat():
    def __init__(self,name):
        self.name = name
    def speak(self):
        return self.name + " says Meow!"

# %%
niko = dog("niko")
felix = cat("felix")

# %%
print(niko.speak())
print(felix.speak())
# Out:
# niko says Woof!
# felix says Meow!

# %%
def pet_speak(pet):
    print(pet.speak())

# %%
pet_speak(niko)
# Out:
# niko says Woof!

# %%
pet_speak(felix)
# Out:
# felix says Meow!

# %%
class Animal():
    def __init__(self,name):
        self.name = name
    def speak(self):
        raise NotImplementedError("Subclass must implement abstract method")

# %%
myanimal = Animal('fred')

# %%
myanimal.speak()
#error coz Animal class does not implement speak method
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 myanimal.speak()
#
# Cell In[20], line 5, in Animal.speak(self)
#       4 def speak(self):
# ----> 5     raise NotImplementedError("Subclass must implement abstract method")
#
# NotImplementedError: Subclass must implement abstract method

# %%
class Dog(Animal):
    def speak(self):
        return self.name + " says Woof!"

# %%
class Cat(Animal):
    def speak(self):
        return self.name + " says Meow!"

# %%
fido = Dog("Fido")

# %%
isis = Cat("Isis")

# %%
print(fido.speak())
# Out:
# Fido says Woof!

# %%
print(isis.speak())
# Out:
# Isis says Meow!

# %%
mylist = [1,2,3,4,5]

# %%
len(mylist)
# Out:
# 5

# %%
class Sample():
    pass

# %%
mysample = Sample()

# %%
len(mysample)
#error coz Sample class does not have __len__ method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 len(mysample)
#
# TypeError: object of type 'Sample' has no len()

# %%
class Book():
    def __init__(self,title,author,pages):
        self.title = title
        self.author = author
        self.pages = pages
    def __str__(self):
        return f"Title: {self.title}, Author: {self.author}, Pages: {self.pages}"
    def __len__(self):
        return self.pages
    def __del__(self):
        print("A book object has been deleted")
    # str method to print the object info

# %%
b = Book("Python sucks","jay",200)

# %%
print(b)
# Out:
# Title: Python sucks, Author: jay, Pages: 200

# %%
str(b)
# Out:
# 'Title: Python sucks, Author: jay, Pages: 200'

# %%
len(b)
# Out:
# 200

# %%
del b
# Out:
# A book object has been deleted
